# %% [markdown]
# # Lecture 17
#
# # Introducing data visualization in Python: Matplotlib
#
# ## Week 6 Friday
#
# ## Miles Chen, PhD
#
# ### Adapted from *Python for Data Science* by Jake VanderPlas

# %% [markdown]
# ## Installation
#
# If you haven't done so already, you may need to update your environment with packages like polars, scipy, and matplotlib.
#
# - `uv pip install -r requirements-unix.txt` (for Mac)
# - `uv pip install -r requirements-win.txt` (for windows)

# %% [markdown]
# ### References:
#
# https://matplotlib.org/stable/api/pyplot_summary.html
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html#module-matplotlib.pyplot
#
#
# ### Always: `import matplotlib.pyplot as plt`

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Creating a simple plot.
#
# First, we create arrays of the values to plot.
#
# We create an array of 500 values from 0 to 2 pi.

# %%
x = np.linspace(0, np.pi * 2, 500)

# %% [markdown]
# We then calculate the y values we wish to plot. In this case, we'll keep it simple and calculate sin of x (in radians).

# %%
y = np.sin(x)

# %% [markdown]
# # Line Plot (The Object-Oriented Interface)
#
# While you can use `plt.plot()`, the modern and highly recommended approach in Matplotlib is the **Object-Oriented (OO) interface**. We create a Figure (`fig`) and an Axes (`ax`) object using `plt.subplots()`.
#
# Prior to calling `plt.show()`, you can call methods on the `ax` object to modify the plot, such as adding a title or changing the axis limits.

# %%
fig, ax = plt.subplots() # no arg 1 fig (axis) and 1 ax (plots)
ax.plot(x, y)
ax.set_title("Sin of x") # optional
ax.set_xlim(0, 2 * np.pi) # optional
plt.show()

# %% [markdown]
# The default behavior of `plot()` is to plot the points and connect them with lines.

# %%
x_val = np.arange(0, 5, 1)
print(x_val)
y_val = np.random.randint(0, 10, 5)
print(y_val)

fig, ax = plt.subplots()
ax.plot(x_val, y_val)
plt.show()
# Out:
# [0 1 2 3 4]
# [3 1 0 2 3]

# %% [markdown]
# # Scatterplot
#
# If you do not want the points to be connected with a line, you can ask for a scatterplot.

# %%
fig, ax = plt.subplots()
ax.scatter(x_val, y_val)
plt.show()

# %% [markdown]
# # Multiple functions or sequences on the same graph
#
# Repeated calls to `ax.plot()` will add lines to the same plot.

# %%
x = np.linspace(0, np.pi * 2, 500)
y = np.sin(x)
z = np.tan(x)
w = np.cos(x)

# %%
fig, ax = plt.subplots()
ax.plot(x, y, 'blue')
ax.plot(x, z, 'red')
plt.show() # the scale of the two functions make this graph undesirable
# should be going to inf

# %%
fig, ax = plt.subplots()
ax.plot(x, y, 'blue')
ax.plot(x, w, 'orange')
plt.show()
# by default adds space between boarders

# %% [markdown]
# # changing labels and axis limits

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('sin(x)')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('sin(x)')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.set_xlim(0, 2 * np.pi) # left & right bounds
ax.axis('equal')  # aspect ratio # investigate later
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x, y, s = 30, marker = 'd', color = 'maroon') # additional options: s is size, marker is shape
ax.scatter(x, w, s = 80, marker = '*', color = 'darkslategrey')
ax.set_xlim([0, .2])
plt.show()

# %% [markdown]
# # Plot options: colors

# %%
# colors
x_line = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x_line, x_line, color = 'b')
ax.plot(x_line, x_line+1, color = 'g')
ax.plot(x_line, x_line+2, color = 'r')
plt.show()

# %% [markdown]
# ### List of colors and single character shortcuts
#
# |character|color|
# |---|---|
# |'b'|blue|
# |'g'|green|
# |'r'|red|
# |'c'|cyan|
# |'m'|magenta|
# |'y'|yellow|
# |'k'|black|
# |'w'|white|
#
# List of Named Colors: https://matplotlib.org/stable/gallery/color/named_colors.html

# %% [markdown]
# # Plot options: line type

# %%
# line style
x_line = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x_line, x_line, linestyle = '-')  # solid
ax.plot(x_line, x_line+1, linestyle = '--') # dashed
ax.plot(x_line, x_line+2, linestyle = '-.') # dash dot
ax.plot(x_line, x_line+3, linestyle = ':')  # dotted
plt.show()

# default behavior uses different colors for multiple lines

# %% [markdown]
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html

# %% [markdown]
# # Plot options: figure size, axis, title

# %%
np.random.seed(1)
x_rand = np.random.random(100)
y_rand = np.random.random(100)

fig, ax = plt.subplots(figsize = (4,4))  # define the properties of the figure first
ax.scatter(x_rand, y_rand)             # then add content
ax.axis('equal')            # alter properties
ax.set_title('2-dimensional random uniform values')
plt.show()

# %% [markdown]
# ### adding point size and color options (Colormaps) to a scatter plot

# %%
z_size = 100 * np.random.randint(1,11,100)  # use for size
w_color = np.random.randint(0,5,100) # use for color group
print(z_size)
print(w_color)
# Out:
# [1000  600  500 1000  600  300  600  700  700  900  800  800  800  300
#   700  100  600  300  200  900  600 1000  500 1000  200  300  100  500
#   800  100  700  300  500  400  700  800  700  400  100  700  500  800
#   700  300 1000  600 1000 1000 1000  900  700  500  300 1000  500  100
#   100  400  500 1000  400 1000  200  300  600  500  100  900  300  400
#  1000 1000  500  500  900  300  200  700  400  900 1000  800  100  600
#   300  300  900  600  100  600 1000  900  700  700  100  500  800  400
#   100  200]
# [2 0 1 4 2 3 4 4 2 1 2 0 3 3 2 0 0 0 0 2 4 0 4 1 2 1 2 4 1 3 1 1 2 4 1 0 2
#  1 2 0 0 3 4 1 0 4 0 3 2 4 3 2 4 2 4 0 0 4 2 2 4 2 3 0 0 4 3 4 3 3 4 0 3 1
#  4 4 3 2 2 2 2 2 0 2 1 2 3 0 0 1 1 3 3 3 1 3 3 3 1 3]

# %%
# Instead of manually mapping array values to string colors, 
# we can leverage Matplotlib's powerful `cmap` argument.
# We map the property size (s) to a variable z
# We map the color (c) to a numeric variable w and let cmap handle the palette.

fig, ax = plt.subplots(figsize = (8,8))
scatter = ax.scatter(x_rand, y_rand, s=z_size, c=w_color, cmap='viridis', alpha=0.6)
ax.axis('equal')
fig.colorbar(scatter, ax=ax, label='Color Group (w_color)')
plt.show()

# %%
# you can change the point markers
fig, ax = plt.subplots()
ax.scatter(x_rand, y_rand, s=z_size, c=w_color, cmap='viridis', marker="*", alpha=0.6)
# But you can't map the markers to a variable
plt.show()

# %% [markdown]
# | character | description           |
# |:---------:|-----------------------|
# |    '.'    | point marker          |
# |    ','    | pixel marker          |
# |    'o'    | circle marker         |
# |    's'    | square marker         |
# |    '*'    | star marker           |
# |    'x'    | x marker              |
#
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/marker_reference.html

# %% [markdown]
# Recomends not to use triangles because it is hard to distinguish different triangle direction.
#
# It is useful to have the triangles point in a certain direction.

# %%
# You can call 'scatter' multiple times to plot different groups, each with its own label
fig, ax = plt.subplots(figsize = (5,5))
ax.scatter(x_rand[0:10], y_rand[0:10], s=100, c='red', marker="*", label='group A')  
ax.scatter(x_rand[11:20], y_rand[11:20], s=100, c='blue', marker="o", label='group B')
ax.legend()
plt.show()

# %%
# You can call 'scatter' multiple times to plot different groups, each with its own label
fig, ax = plt.subplots(figsize = (5,5))
ax.scatter(x_rand[0:10], y_rand[0:10], s=100, c='red', marker="*", label='group A')  
ax.scatter(x_rand[11:20], y_rand[11:20], s=100, c='blue', marker="o", label='group B')
ax.legend(
    loc= 'center left',
    bbox_to_anchor=(0,0),
    frameon=True
)
plt.show()

# %% [markdown]
# # Complex layouts with subplots

# %%
# Modern Subplots approach using plt.subplots() array unpacking
fig, axes = plt.subplots(2, 3, figsize=(9, 6))

print(axes.flatten())
print(list(enumerate(axes.flatten())))

for i, ax in enumerate(axes.flatten()):
    # ax.text adds text, first two will be the xy position, the character string
    ax.text(0.5, 0.5, f'plot {i}', fontsize=14, ha='center')  
    ax.set_xticks([]) # hide ticks for visual clarity
    ax.set_yticks([])

plt.show()
# Out:
# [<Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]
# [(0, <Axes: >), (1, <Axes: >), (2, <Axes: >), (3, <Axes: >), (4, <Axes: >), (5, <Axes: >)]

# %% [markdown]
# # Subplots example

# %%
x = np.linspace(0, np.pi * 2, 500)
y = np.sin(x)
z = np.tan(x)
w = np.cos(x)

fig, axes = plt.subplots(2, 2, figsize=(10, 8)) # one canvas that divides into 4 plots

axes[0, 0].plot(x, y)
axes[0, 0].set_title("sin(x)")

axes[0, 1].plot(x, w)
axes[0, 1].set_title("cos(x)")

axes[1, 0].plot(x, z)
axes[1, 0].set_title("tan(x)")
axes[1, 0].set_ylim(-5, 5) # necessary for tan to look clean

axes[1, 1].plot(x, y, 'red')
axes[1, 1].plot(x, w, 'blue')
axes[1, 1].set_title("sin and cos")

plt.tight_layout() # Good practice to prevent overlapping labels
plt.show()

# %%
# More Complicated Grids using GridSpec and add_subplot
fig = plt.figure(figsize=(10, 5))
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.4)

ax1 = fig.add_subplot(grid[0, 0])
ax1.scatter(x_rand[0:10], y_rand[0:10])

ax2 = fig.add_subplot(grid[0, 1:3]) # top row, columns 1:3
ax2.hist(x_rand)

ax3 = fig.add_subplot(grid[1, :2]) # bottom row, columns 0:2
ax3.hist(y_rand)

ax4 = fig.add_subplot(grid[1, 2])
ax4.plot(x_rand[0:4], y_rand[0:4], c='r')

plt.show()

# %% [markdown]
# ### Histograms

# %%
data = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(data)
plt.show()

# %%
# alter bins and color options
fig, ax = plt.subplots()
ax.hist(data, bins=25, alpha=0.5, color='steelblue', edgecolor='black')
plt.show()

# %%
x1 = np.random.normal(0, 0.8, 10000)
x2 = np.random.normal(-2, 1, 10000)
x3 = np.random.normal(3, 2, 10000)

kwargs = dict(histtype='stepfilled', alpha=0.6, density=True, bins=25, edgecolor='black')

fig, ax = plt.subplots()
ax.hist(x1, **kwargs, color='navy') # **kwargs is basically copy & paste
ax.hist(x2, **kwargs, color="purple")
ax.hist(x3, **kwargs)
plt.show()

# %%
# 2d histograms
mean = [0, 0]
cov = [[1, 1], 
       [1, 2]]
x_norm, y_norm = np.random.multivariate_normal(mean, cov, 10000).T

fig, ax = plt.subplots()
h = ax.hist2d(x_norm, y_norm, bins=30, cmap='Blues')
cb = fig.colorbar(h[3], ax=ax)
cb.set_label('counts in bin')
plt.show()

# %%
fig, ax = plt.subplots()
hb = ax.hexbin(x_norm, y_norm, gridsize=30, cmap='Blues')
cb = fig.colorbar(hb, ax=ax, label='count in bin')
plt.show()

# %% [markdown]
# ## two dimensional functions

# %%
x_grid = np.linspace(-3, 3, 101)
y_grid = np.linspace(-3, 3, 101)
X, Y = np.meshgrid(x_grid, y_grid)

def g(x, y): 
    return np.exp(-(x**2)) * np.exp(-(y**2))

Z = g(X, Y)

# %%
fig, ax = plt.subplots()
ax.contour(X, Y, Z)
ax.axis('equal')
plt.show()

# %%
fig, ax = plt.subplots()
im = ax.imshow(Z, origin='lower')
fig.colorbar(im, ax=ax)
plt.show()

# %% [markdown]
# # Plotting Directly from a Pandas Data Frame

# %%
ts = pd.Series(np.random.randn(1000),
   index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index = ts.index, columns = list('ABCD'))
df = df.cumsum()
df.plot() # Pandas returns an Axes object automatically
# Out:
# <Axes: >

# %%
df.loc[:, 'A':'B'].plot()
# Out:
# <Axes: >

# %%
df.iloc[0:100, :2].plot() # plotting a subset of the data
# Out:
# <Axes: >

# %%
df2 = pd.DataFrame(np.random.randint(0,10,size = (5, 4)), columns=['CA', 'NY', 'TX', 'OH'], 
                   index = ["Tech","Agriculture","Manufacturing","Service","Other"])
df2.plot.bar()
plt.title("Type by State")
plt.show()

# %%
df2.T.plot.bar(stacked=True)
plt.title("State by Type")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') # positions the legend outside the box
plt.show()

# %% [markdown]
# ### Titanic Dataset

# %%
# Using a highly stable remote repository for the dataset to prevent link rot
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
titanic = pd.read_csv(url)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.Survived = titanic.Survived.astype("category")
titanic.Survived = titanic.Survived.cat.rename_categories({0: "died", 1:"survived"})
pd.crosstab(titanic.Sex, titanic.Survived).plot(kind = "bar", stacked = True)
plt.show()

# %%
titanic["is_child"] = titanic.Age < 8
pd.crosstab(titanic.is_child, titanic.Survived, normalize = 0).plot(kind = "bar", stacked = True) # normalize gives proportion out of 100%
plt.show()

# %%
titanic_summary = titanic.groupby(["Sex", "is_child", "Survived"], observed = False)["PassengerId"].count()
row_totals = titanic_summary.unstack().sum(axis = 1)
titanic_summary.unstack().div(row_totals, axis = 0).plot(kind = "bar", stacked = True)
plt.show()

# %% [markdown]
# #### Create a data frame consisting of random die rolls (Central Limit Theorem)

# %%
df_dice = pd.DataFrame(np.random.randint(1, 7, 60000), columns = ['one'])
df_dice['two'] = df_dice['one'] + np.random.randint(1, 7, 60000)
df_dice['three'] = df_dice['two'] + np.random.randint(1, 7, 60000)
df_dice['four'] = df_dice['three'] + np.random.randint(1, 7, 60000)
df_dice['five'] = df_dice['four'] + np.random.randint(1, 7, 60000)

df_dice.plot.hist(bins = 30, alpha = 0.5)
plt.show()
